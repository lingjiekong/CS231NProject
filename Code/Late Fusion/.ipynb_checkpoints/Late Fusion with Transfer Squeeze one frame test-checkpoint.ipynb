# %% [markdown]
# # Late Fusion adapted by Transfer Squeeze Net

# %% [markdown]
# We will implement late fusion which is introduced in paper "Large-scale Video Classification with Convolutional Neural Network"
#
# The pipeline will be described in detail as below.
#
# First, we will clip 5 frames from a video that we want to classify.
#
# Second, we will pass the 5 frames individually through trained squeeze net on image net to get a 1000 result which is used in image net label.
#
# Third, we will concatinate 5 1000 result together to train another FC layer to give the labels that we want to classify our video.
#
# Above all, we will implement these late fusion approach and fine tune hyperparameters to yeild the best possbile result

# %% [markdown]
# # load Squeeze Net model and other libraries

# %%
# As usual, a bit of setup
from __future__ import print_function
import time, os, json
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import math
import json

from cs231n.classifiers.squeezenet import SqueezeNet
from cs231n.data_utils import load_tiny_imagenet
from cs231n.image_utils import preprocess_image, deprocess_image
from cs231n.image_utils import SQUEEZENET_MEAN, SQUEEZENET_STD


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

def get_session():
    """Create a session that dynamically allocates memory."""
    # See: https://www.tensorflow.org/tutorials/using_gpu#allowing_gpu_memory_growth
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    session = tf.Session(config=config)
    return session

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # load dataset and preprocess
#  - First, run DataProprocessing Notebook to get label (Y) and data (X) txt file.
#  - Second, move label and data txt file into this notebook foler
#  - third, run the code below

# %%
def get_data(num_training = 81, num_validation = 10, num_test = 10):
    ''' 
    load the training data provided by Jake 
    
    '''
    # load the raw data
    with open('label_squeeze.json', 'r') as fp:
        y_total = json.load(fp)
        y_total = np.array(y_total)
    with open('data_squeeze.json', 'r') as fp:
        x_total = json.load(fp)
        x_total = np.array(x_total)
        
    # Subsample the data
    # training data
    mask_train = range(0, num_training)
    x_train = x_total[mask_train]
    y_train = y_total[mask_train]
    # validation data
    mask_val = range(num_training, num_training + num_validation)
    x_val = x_total[mask_val]
    y_val = y_total[mask_val]
    # test data
    mask_test = range(num_training+num_validation, num_training+num_validation+num_test)
    x_test = x_total[mask_test]
    y_test = y_total[mask_test]
    
    # normalize the data: subtract the mean
    mean_video = np.floor(np.mean(x_train, axis=0))
    x_train = x_train - mean_video
    x_val = x_val - mean_video
    x_test = x_test - mean_video
    
    return x_train, y_train, x_val, y_val, x_test, y_test

x_train, y_train, x_val, y_val, x_test, y_test = get_data()

print('Train data shape: ', x_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', x_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', x_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (81, 5, 224, 224, 3)
# Train labels shape:  (81,)
# Validation data shape:  (10, 5, 224, 224, 3)
# Validation labels shape:  (10,)
# Test data shape:  (10, 5, 224, 224, 3)
# Test labels shape:  (10,)

# %% [markdown]
# # train last layer in squeeze net

# %%
tf.reset_default_graph()
sess = get_session()
SAVE_PATH = 'cs231n/datasets/squeezenet.ckpt'
model = SqueezeNet(save_path=SAVE_PATH, sess=sess)

NUM_CLASSES = 4 

with tf.variable_scope('classifier_squeeze'):
    with tf.variable_scope('layer0'):
        x = model.features
    with tf.variable_scope('layer1'):
        W = tf.get_variable("weights",shape=[1,1,512,NUM_CLASSES])
        b = tf.get_variable("bias",shape=[NUM_CLASSES])
        x = tf.nn.conv2d(x,W,[1,1,1,1],"VALID")
        x = tf.nn.bias_add(x,b)
    with tf.variable_scope('layer2'):
        x = tf.nn.relu(x)
    with tf.variable_scope('layer3'):
        x = tf.nn.avg_pool(x,[1,13,13,1],strides=[1,13,13,1],padding='VALID')
        
model.classifier = tf.reshape(x,[-1, NUM_CLASSES])
mean_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=tf.one_hot(model.labels, NUM_CLASSES), logits=model.classifier))
classifier_squeeze_variable = tf.contrib.framework.get_variables('classifier_squeeze')
optimizer = tf.train.AdamOptimizer(1e-2) # select optimizer and set learning rate
train_step = optimizer.minimize(mean_loss, var_list = classifier_squeeze_variable)
# Out:
# INFO:tensorflow:Restoring parameters from cs231n/datasets/squeezenet.ckpt

# %%
def run_model(session, predict, loss_val, Xd, yd,
              epochs=1, batch_size=40, print_every=100,
              training=None, plot_losses=False):
    # have tensorflow compute accuracy
    correct_prediction = tf.equal(tf.argmax(predict,1), model.labels)
    correct_label = tf.argmax(predict,1)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    # shuffle indicies
    train_indicies = np.arange(Xd.shape[0])
    np.random.shuffle(train_indicies)

    training_now = training is not None
    
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    variables = [mean_loss, correct_prediction, correct_label, accuracy]
    
    if training_now:
        variables[-1] = training
    
    # counter 
    iter_cnt = 0
    for e in range(epochs):
        # keep track of losses and accuracy
        correct = 0
        losses = []
        # make sure we iterate over the dataset once
        for i in range(int(math.ceil(Xd.shape[0]/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%Xd.shape[0]
            idx = train_indicies[start_idx:start_idx+batch_size]
            
            # create a feed dictionary for this batch
            feed_dict = {model.image: Xd[idx,:],
                         model.labels: yd[idx]}
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step
            loss, corr, label, _ = session.run(variables,feed_dict=feed_dict)
            
            # aggregate performance stats
            losses.append(loss*actual_batch_size)
            correct += np.sum(corr)
            
            # print every now and then
            if training_now and (iter_cnt % print_every) == 0:
                print("Iteration {0}: with minibatch training loss = {1:.3g} and accuracy of {2:.2g}"\
                      .format(iter_cnt,loss,np.sum(corr)/actual_batch_size))
            iter_cnt += 1
        total_correct = correct/Xd.shape[0]
        total_loss = np.sum(losses)/Xd.shape[0]
        print("Epoch {2}, Overall loss = {0:.3g} and accuracy of {1:.3g}"\
              .format(total_loss,total_correct,e+1))
        print ("label is %d" %label)
        if plot_losses:
            plt.plot(losses)
            plt.grid(True)
            plt.title('Epoch {} Loss'.format(e+1))
            plt.xlabel('minibatch number')
            plt.ylabel('minibatch loss')
            plt.show()
    return total_loss,total_correct

# %%
sess.run(tf.global_variables_initializer())
run_model(sess,model.classifier,mean_loss,x_train[0],np.repeat(y_train[0],5),100,1,1000,train_step,True)
# Out:
# Iteration 0: with minibatch training loss = 1.33 and accuracy of 0
# Epoch 1, Overall loss = 0.854 and accuracy of 0.8
# label is 0
# Epoch 2, Overall loss = 0.299 and accuracy of 1
# label is 0
# Epoch 3, Overall loss = 0.129 and accuracy of 1
# label is 0
# Epoch 4, Overall loss = 0.0637 and accuracy of 1
# label is 0
# Epoch 5, Overall loss = 0.037 and accuracy of 1
# label is 0
# Epoch 6, Overall loss = 0.0246 and accuracy of 1
# label is 0
# Epoch 7, Overall loss = 0.0182 and accuracy of 1
# label is 0
# Epoch 8, Overall loss = 0.0146 and accuracy of 1
# label is 0
# Epoch 9, Overall loss = 0.0123 and accuracy of 1
# label is 0
# Epoch 10, Overall loss = 0.0107 and accuracy of 1
# label is 0
# Epoch 11, Overall loss = 0.00965 and accuracy of 1
# label is 0
# Epoch 12, Overall loss = 0.00882 and accuracy of 1
# label is 0
# Epoch 13, Overall loss = 0.00815 and accuracy of 1
# label is 0
# Epoch 14, Overall loss = 0.00761 and accuracy of 1
# label is 0
# Epoch 15, Overall loss = 0.00714 and accuracy of 1
# label is 0
# Epoch 16, Overall loss = 0.00673 and accuracy of 1
# label is 0
# Epoch 17, Overall loss = 0.00636 and accuracy of 1
# label is 0
# Epoch 18, Overall loss = 0.00603 and accuracy of 1
# label is 0
# Epoch 19, Overall loss = 0.00573 and accuracy of 1
# label is 0
# Epoch 20, Overall loss = 0.00545 and accuracy of 1
# label is 0
# Epoch 21, Overall loss = 0.00519 and accuracy of 1
# label is 0
# Epoch 22, Overall loss = 0.00495 and accuracy of 1
# label is 0
# Epoch 23, Overall loss = 0.00473 and accuracy of 1
# label is 0
# Epoch 24, Overall loss = 0.00453 and accuracy of 1
# label is 0
# Epoch 25, Overall loss = 0.00433 and accuracy of 1
# label is 0
# Epoch 26, Overall loss = 0.00415 and accuracy of 1
# label is 0
# Epoch 27, Overall loss = 0.00398 and accuracy of 1
# label is 0
# Epoch 28, Overall loss = 0.00383 and accuracy of 1
# label is 0
# Epoch 29, Overall loss = 0.00368 and accuracy of 1
# label is 0
# Epoch 30, Overall loss = 0.00354 and accuracy of 1
# label is 0
# Epoch 31, Overall loss = 0.00341 and accuracy of 1
# label is 0
# Epoch 32, Overall loss = 0.00328 and accuracy of 1
# label is 0
# Epoch 33, Overall loss = 0.00317 and accuracy of 1
# label is 0
# Epoch 34, Overall loss = 0.00306 and accuracy of 1
# label is 0
# Epoch 35, Overall loss = 0.00295 and accuracy of 1
# label is 0
# Epoch 36, Overall loss = 0.00285 and accuracy of 1
# label is 0
# Epoch 37, Overall loss = 0.00276 and accuracy of 1
# label is 0
# Epoch 38, Overall loss = 0.00267 and accuracy of 1
# label is 0
# Epoch 39, Overall loss = 0.00258 and accuracy of 1
# label is 0
# Epoch 40, Overall loss = 0.0025 and accuracy of 1
# label is 0
# Epoch 41, Overall loss = 0.00243 and accuracy of 1
# label is 0
# Epoch 42, Overall loss = 0.00235 and accuracy of 1
# label is 0
# Epoch 43, Overall loss = 0.00229 and accuracy of 1
# label is 0
# Epoch 44, Overall loss = 0.00222 and accuracy of 1
# label is 0
# Epoch 45, Overall loss = 0.00216 and accuracy of 1
# label is 0
# Epoch 46, Overall loss = 0.0021 and accuracy of 1
# label is 0
# Epoch 47, Overall loss = 0.00204 and accuracy of 1
# label is 0
# Epoch 48, Overall loss = 0.00198 and accuracy of 1
# label is 0
# Epoch 49, Overall loss = 0.00193 and accuracy of 1
# label is 0
# Epoch 50, Overall loss = 0.00188 and accuracy of 1
# label is 0
# Epoch 51, Overall loss = 0.00183 and accuracy of 1
# label is 0
# Epoch 52, Overall loss = 0.00178 and accuracy of 1
# label is 0
# Epoch 53, Overall loss = 0.00174 and accuracy of 1
# label is 0
# Epoch 54, Overall loss = 0.0017 and accuracy of 1
# label is 0
# Epoch 55, Overall loss = 0.00166 and accuracy of 1
# label is 0
# Epoch 56, Overall loss = 0.00162 and accuracy of 1
# label is 0
# Epoch 57, Overall loss = 0.00158 and accuracy of 1
# label is 0
# Epoch 58, Overall loss = 0.00154 and accuracy of 1
# label is 0
# Epoch 59, Overall loss = 0.00151 and accuracy of 1
# label is 0
# Epoch 60, Overall loss = 0.00147 and accuracy of 1
# label is 0
# Epoch 61, Overall loss = 0.00144 and accuracy of 1
# label is 0
# Epoch 62, Overall loss = 0.00141 and accuracy of 1
# label is 0
# Epoch 63, Overall loss = 0.00138 and accuracy of 1
# label is 0
# Epoch 64, Overall loss = 0.00135 and accuracy of 1
# label is 0
# Epoch 65, Overall loss = 0.00132 and accuracy of 1
# label is 0
# Epoch 66, Overall loss = 0.00129 and accuracy of 1
# label is 0
# Epoch 67, Overall loss = 0.00126 and accuracy of 1
# label is 0
# Epoch 68, Overall loss = 0.00124 and accuracy of 1
# label is 0
# Epoch 69, Overall loss = 0.00121 and accuracy of 1
# label is 0
# Epoch 70, Overall loss = 0.00119 and accuracy of 1
# label is 0
# Epoch 71, Overall loss = 0.00117 and accuracy of 1
# label is 0
# Epoch 72, Overall loss = 0.00114 and accuracy of 1
# label is 0
# Epoch 73, Overall loss = 0.00112 and accuracy of 1
# label is 0
# Epoch 74, Overall loss = 0.0011 and accuracy of 1
# label is 0
# Epoch 75, Overall loss = 0.00108 and accuracy of 1
# label is 0
# Epoch 76, Overall loss = 0.00106 and accuracy of 1
# label is 0
# Epoch 77, Overall loss = 0.00104 and accuracy of 1
# label is 0
# Epoch 78, Overall loss = 0.00102 and accuracy of 1
# label is 0
# Epoch 79, Overall loss = 0.001 and accuracy of 1
# label is 0
# Epoch 80, Overall loss = 0.000984 and accuracy of 1
# label is 0
# Epoch 81, Overall loss = 0.000967 and accuracy of 1
# label is 0
# Epoch 82, Overall loss = 0.00095 and accuracy of 1
# label is 0
# Epoch 83, Overall loss = 0.000933 and accuracy of 1
# label is 0
# Epoch 84, Overall loss = 0.000917 and accuracy of 1
# label is 0
# Epoch 85, Overall loss = 0.000902 and accuracy of 1
# label is 0
# Epoch 86, Overall loss = 0.000887 and accuracy of 1
# label is 0
# Epoch 87, Overall loss = 0.000872 and accuracy of 1
# label is 0
# Epoch 88, Overall loss = 0.000858 and accuracy of 1
# label is 0
# Epoch 89, Overall loss = 0.000844 and accuracy of 1
# label is 0
# Epoch 90, Overall loss = 0.00083 and accuracy of 1
# label is 0
# Epoch 91, Overall loss = 0.000817 and accuracy of 1
# label is 0
# Epoch 92, Overall loss = 0.000804 and accuracy of 1
# label is 0
# Epoch 93, Overall loss = 0.000791 and accuracy of 1
# label is 0
# Epoch 94, Overall loss = 0.000779 and accuracy of 1
# label is 0
# Epoch 95, Overall loss = 0.000767 and accuracy of 1
# label is 0
# Epoch 96, Overall loss = 0.000755 and accuracy of 1
# label is 0
# Epoch 97, Overall loss = 0.000744 and accuracy of 1
# label is 0
# Epoch 98, Overall loss = 0.000733 and accuracy of 1
# label is 0
# Epoch 99, Overall loss = 0.000722 and accuracy of 1
# label is 0
# Epoch 100, Overall loss = 0.000711 and accuracy of 1
# label is 0
# (0.00071135044563561676, 1.0)
